# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset("tips")
sns.lineplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# how to use template datasets

import seaborn as sns
import pandas as pd

df = sns.load_dataset('tips')
df.head(10)

df.to_csv('tips.csv')

# %%
pip install pandas_profiling
# Out:
# Collecting pandas_profilingNote: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\Quantum\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script phik_trial.exe is installed in 'c:\Users\Quantum\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pandas_profiling.exe is installed in 'c:\Users\Quantum\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 20.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\Users\Quantum\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Requirement already satisfied: joblib~=1.1.0 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from pandas_profiling) (1.1.0)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from pandas_profiling) (2.1.1)
# Collecting multimethod>=1.4
#   Using cached multimethod-1.8-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from pandas_profiling) (1.7.3)
# Collecting tqdm>=4.48.2
#   Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# Collecting visions[type_image_path]==0.7.4
#   Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from pandas_profiling) (1.4.0)
# Collecting tangled-up-in-unicode==0.2.0
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# Collecting htmlmin>=0.1.12
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
# Collecting phik>=0.11.1
#   Downloading phik-0.12.2-cp39-cp39-win_amd64.whl (685 kB)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from pandas_profiling) (3.5.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from pandas_profiling) (3.1.1)
# Requirement already satisfied: requests>=2.24.0 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from pandas_profiling) (2.27.1)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from pandas_profiling) (0.11.2)
# Collecting missingno>=0.4.2
#   Using cached missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Collecting pydantic>=1.8.1
#   Downloading pydantic-1.9.2-cp39-cp39-win_amd64.whl (2.0 MB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from pandas_profiling) (1.22.1)
# Collecting PyYAML>=5.0.0
#   Downloading PyYAML-6.0-cp39-cp39-win_amd64.whl (151 kB)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from tqdm>=4.48.2->pandas_profiling) (0.4.4)
# Collecting networkx>=2.4
#   Downloading networkx-2.8.5-py3-none-any.whl (2.0 MB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (21.4.0)
# Collecting imagehash; extra == "type_image_path"
#   Using cached ImageHash-4.2.1.tar.gz (812 kB)
# Requirement already satisfied: Pillow; extra == "type_image_path" in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (9.0.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas_profiling) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas_profiling) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (4.29.1)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.24.0->pandas_profiling) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.24.0->pandas_profiling) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.24.0->pandas_profiling) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.24.0->pandas_profiling) (2.0.12)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from pydantic>=1.8.1->pandas_profiling) (4.0.1)
# Requirement already satisfied: six in c:\users\quantum\appdata\local\programs\python\python39\lib\site-packages (from imagehash; extra == "type_image_path"->visions[type_image_path]==0.7.4->pandas_profiling) (1.16.0)
# Collecting PyWavelets
#   Downloading PyWavelets-1.3.0-cp39-cp39-win_amd64.whl (4.2 MB)
# Using legacy 'setup.py install' for htmlmin, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for imagehash, since package 'wheel' is not installed.
# Installing collected packages: multimethod, tqdm, tangled-up-in-unicode, networkx, PyWavelets, imagehash, visions, htmlmin, phik, missingno, pydantic, PyYAML, pandas-profiling
#     Running setup.py install for imagehash: started
#     Running setup.py install for imagehash: finished with status 'done'
#     Running setup.py install for htmlmin: started
#     Running setup.py install for htmlmin: finished with status 'done'
# Successfully installed PyWavelets-1.3.0 PyYAML-6.0 htmlmin-0.1.12 imagehash-4.2.1 missingno-0.5.1 multimethod-1.8 networkx-2.8.5 pandas-profiling-3.2.0 phik-0.12.2 pydantic-1.9.2 tangled-up-in-unicode-0.2.0 tqdm-4.64.0 visions-0.7.4

# %%
import pandas as pd
import pandas_profiling as pp 

pp.ProfileReport(df)
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_profiling\profile_report.py:418, in ProfileReport._repr_html_(self)
#     416 def _repr_html_(self) -> None:
#     417     """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 418     self.to_notebook_iframe()
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_profiling\profile_report.py:398, in ProfileReport.to_notebook_iframe(self)
#     396 with warnings.catch_warnings():
#     397     warnings.simplefilter("ignore")
# --> 398     display(get_notebook_iframe(self.config, self))
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_profiling\report\presentation\flavours\widget\notebook.py:75, in get_notebook_iframe(config, profile)
#      73     output = get_notebook_iframe_src(config, profile)
#      74 elif attribute == IframeAttribute.srcdoc:
# ---> 75     output = get_notebook_iframe_srcdoc(config, profile)
#      76 else:
#      77     raise ValueError(
#      78         f'Iframe Attribute can be "src" or "srcdoc" (current: {attribute}).'
#      79     )
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_profiling\report\presentation\flavours\widget\notebook.py:29, in get_notebook_iframe_srcdoc(config, profile)
#      27 width = config.notebook.iframe.width
#      28 height = config.notebook.iframe.height
# ---> 29 src = html.escape(profile.to_html())
#      31 iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#      33 return HTML(iframe)
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_profiling\profile_report.py:368, in ProfileReport.to_html(self)
#     360 def to_html(self) -> str:
#     361     """Generate and return complete template as lengthy string
#     362         for using with frameworks.
#     363
#    (...)
#     366
#     367     """
# --> 368     return self.html
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_profiling\profile_report.py:185, in ProfileReport.html(self)
#     182 @property
#     183 def html(self) -> str:
#     184     if self._html is None:
# --> 185         self._html = self._render_html()
#     186     return self._html
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_profiling\profile_report.py:287, in ProfileReport._render_html(self)
#     284 def _render_html(self) -> str:
#     285     from pandas_profiling.report.presentation.flavours import HTMLReport
# --> 287     report = self.report
#     289     with tqdm(
#     290         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     291     ) as pbar:
#     292         html = HTMLReport(copy.deepcopy(report)).render(
#     293             nav=self.config.html.navbar_show,
#     294             offline=self.config.html.use_local_assets,
#    (...)
#     302             version=self.description_set["package"]["pandas_profiling_version"],
#     303         )
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_profiling\profile_report.py:179, in ProfileReport.report(self)
#     176 @property
#     177 def report(self) -> Root:
#     178     if self._report is None:
# --> 179         self._report = get_report_structure(self.config, self.description_set)
#     180     return self._report
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_profiling\profile_report.py:161, in ProfileReport.description_set(self)
#     158 @property
#     159 def description_set(self) -> Dict[str, Any]:
#     160     if self._description_set is None:
# --> 161         self._description_set = describe_df(
#     162             self.config,
#     163             self.df,
#     164             self.summarizer,
#     165             self.typeset,
#     166             self._sample,
#     167         )
#     168     return self._description_set
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_profiling\model\describe.py:71, in describe(config, df, summarizer, typeset, sample)
#      69 # Variable-specific
#      70 pbar.total += len(df.columns)
# ---> 71 series_description = get_series_descriptions(
#      72     config, df, summarizer, typeset, pbar
#      73 )
#      75 pbar.set_postfix_str("Get variable types")
#      76 pbar.total += 1
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\multimethod\__init__.py:312, in multimethod.__call__(self, *args, **kwargs)
#     310 func = self[tuple(func(arg) for func, arg in zip(self.type_checkers, args))]
#     311 try:
# --> 312     return func(*args, **kwargs)
#     313 except TypeError as ex:
#     314     raise DispatchError(f"Function {func.__code__}") from ex
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_profiling\model\pandas\summary_pandas.py:92, in pandas_get_series_descriptions(config, df, summarizer, typeset, pbar)
#      89 else:
#      90     # TODO: use `Pool` for Linux-based systems
#      91     with multiprocessing.pool.ThreadPool(pool_size) as executor:
# ---> 92         for i, (column, description) in enumerate(
#      93             executor.imap_unordered(multiprocess_1d, args)
#      94         ):
#      95             pbar.set_postfix_str(f"Describe variable:{column}")
#      96             series_description[column] = description
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\multiprocessing\pool.py:870, in IMapIterator.next(self, timeout)
#     868 if success:
#     869     return value
# --> 870 raise value
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\multiprocessing\pool.py:125, in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_profiling\model\pandas\summary_pandas.py:72, in pandas_get_series_descriptions.<locals>.multiprocess_1d(args)
#      62 """Wrapper to process series in parallel.
#      63
#      64 Args:
#    (...)
#      69     A tuple with column and the series description.
#      70 """
#      71 column, series = args
# ---> 72 return column, describe_1d(config, series, summarizer, typeset)
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\multimethod\__init__.py:312, in multimethod.__call__(self, *args, **kwargs)
#     310 func = self[tuple(func(arg) for func, arg in zip(self.type_checkers, args))]
#     311 try:
# --> 312     return func(*args, **kwargs)
#     313 except TypeError as ex:
#     314     raise DispatchError(f"Function {func.__code__}") from ex
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_profiling\model\pandas\summary_pandas.py:43, in pandas_describe_1d(config, series, summarizer, typeset)
#      40 # get `infer_dtypes` (bool) from config
#      41 if config.infer_dtypes:
#      42     # Infer variable types
# ---> 43     vtype = typeset.infer_type(series)
#      44     series = typeset.cast_to_inferred(series)
#      45 else:
#      46     # Detect variable types from pandas dataframe (df.dtypes).
#      47     # [new dtypes, changed using `astype` function are now considered]
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\visions\typesets\typeset.py:311, in VisionsTypeset.infer_type(self, data)
#     301 def infer_type(self, data: Sequence) -> Union[T, Dict[str, T]]:
#     303     """The inferred type found using all type relations.
#     304
#     305     Args:
#    (...)
#     309         A dictionary of {name: type} pairs in the case of DataFrame input or a type
#     310     """
# --> 311     _, paths, _ = self.infer(data)
#     312     return get_type_from_path(paths)
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\visions\typesets\typeset.py:299, in VisionsTypeset.infer(self, data)
#     287 def infer(self, data: Sequence) -> Tuple[Sequence, Any, dict]:
#     288     """The results found after considering all relations.
#     289
#     290     Notes:
#    (...)
#     297         A tuple of the coerced sequence, visited nodes and state
#     298     """
# --> 299     return traverse_graph(data, self.root_node, self.relation_graph)
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\functools.py:877, in singledispatch.<locals>.wrapper(*args, **kw)
#     873 if not args:
#     874     raise TypeError(f'{funcname} requires at least '
#     875                     '1 positional argument')
# --> 877 return dispatch(args[0].__class__)(*args, **kw)
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\visions\backends\pandas\traversal.py:16, in _traverse_graph_series(series, root_node, graph)
#      12 @traverse_graph.register(pd.Series)
#      13 def _traverse_graph_series(
#      14     series: pd.Series, root_node: T, graph: nx.DiGraph
#      15 ) -> Tuple[pd.Series, List[T], dict]:
# ---> 16     return traverse_graph_with_series(root_node, series, graph)
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\visions\typesets\typeset.py:146, in traverse_graph_with_series(base_type, series, graph, path, state)
#     144 for vision_type in graph.successors(base_type):
#     145     relation = graph[base_type][vision_type]["relationship"]
# --> 146     if relation.is_relation(series, state):
#     147         series = relation.transform(series, state)
#     148         return traverse_graph_with_series(vision_type, series, graph, path, state)
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\visions\relations\relations.py:60, in TypeRelation.is_relation(self, series, state)
#      58 if state is None:
#      59     state = {}
# ---> 60 return self.relationship(series, state)
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\multimethod\__init__.py:312, in multimethod.__call__(self, *args, **kwargs)
#     310 func = self[tuple(func(arg) for func, arg in zip(self.type_checkers, args))]
#     311 try:
# --> 312     return func(*args, **kwargs)
#     313 except TypeError as ex:
#     314     raise DispatchError(f"Function {func.__code__}") from ex
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\visions\backends\pandas\series_utils.py:60, in series_not_empty.<locals>.inner(series, *args, **kwargs)
#      58 if series.empty:
#      59     return False
# ---> 60 return fn(series, *args, **kwargs)
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_profiling\model\typeset.py:43, in series_handle_nulls.<locals>.inner(series, state, *args, **kwargs)
#      40     if series.empty:
#      41         return False
# ---> 43 return fn(series, state, *args, **kwargs)
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_profiling\model\typeset.py:146, in typeset_types.<locals>.Boolean.contains_op(series, state)
#     143     except:  # noqa: E722
#     144         return False
# --> 146 return pdt.is_bool_dtype(series)
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\dtypes\common.py:1322, in is_bool_dtype(arr_or_dtype)
#    1319     return False
#    1321 if isinstance(dtype, CategoricalDtype):
# -> 1322     arr_or_dtype = arr_or_dtype.categories
#    1323     # now we use the special definition for Index
#    1325 if isinstance(arr_or_dtype, ABCIndex):
#    1326     # Allow Index[object] that is all-bools or Index["boolean"]
#
# File c:\Users\Quantum\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:5583, in NDFrame.__getattr__(self, name)
#    5576 if (
#    5577     name not in self._internal_names_set
#    5578     and name not in self._metadata
#    5579     and name not in self._accessors
#    5580     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5581 ):
#    5582     return self[name]
# -> 5583 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'categories'
